# %% [markdown]
# # Langchain project
#
# Go through the subscribed channels and get answers to questions like:
# - Divide the subscribers based on their description into 20 categories.

# %% [markdown]
# ## Gettting list of my subscribes

# %% [markdown]
# ### Using official google api

# %%
# Getting list of channels I have subscribed from youtube
import google_auth_oauthlib.flow
import googleapiclient.discovery
import googleapiclient.errors
from google_auth_oauthlib.flow import InstalledAppFlow

with open('api_key', 'r') as f:
    api_key = f.read()
print(api_key) 
# Read client_secrets.json for the API Key
json = {}
with open('client_secret_14184275437-afvrf8t8ftgo32ivb1a4bre5vbjabb15.apps\
    .googleusercontent.com.json', 'r') as f:
    json = f.read()

#  Connecting with API and verifying connection

# Define the scopes required for your API access
SCOPES = ['https://www.googleapis.com/auth/youtube.readonly']

# Load the client secret file
flow = InstalledAppFlow.from_client_secrets_file('client_secret_desktop_app.json', scopes=SCOPES)
credentials = flow.run_local_server(port=0)
access_token = credentials.token
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 7
#       4 import googleapiclient.errors
#       5 from google_auth_oauthlib.flow import InstalledAppFlow
# ----> 7 with open('api_key', 'r') as f:
#       8     api_key = f.read()
#       9 print(api_key)
#
# File ~/mambaforge/envs/fastai/lib/python3.11/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'api_key'

# %%
# Getting some list of my channel

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, credentials=credentials)


request = youtube.subscriptions().list(
    part="snippet,contentDetails",
    mine=True
)
response = request.execute()

all_results = []

while request is not None:
    response = request.execute()
    items = response.get("items", [])
    all_results.extend(items)
    request = youtube.subscriptions().list_next(request, response)

total_results = len(all_results)
print(f"Total results: {total_results}")
print(all_results)
# Out:
# Total results: 415
# [{'kind': 'youtube#subscription', 'etag': 'Cx76hlf1aCuc1Y031-4FlGSEI18', 'id': 'SIHu8KibTrTIIVKBOCVnFQVre9G6BFtDmxV4zTg-SC4', 'snippet': {'publishedAt': '2022-02-17T16:49:00.36575Z', 'title': 'Rational World', 'description': 'यह चैनल समाज में फैले अंधविश्वास, पाखंड को तथा उसे फ़ैलाने वाले उसके ठेकेदारों को बेनकाब करने के लिए प्रतिबद्ध है ताकि मानव सभ्यता एक बेहतर जीवन जी सके | सिर्फ वैज्ञानिक सोच ही मानव भविष्य को बेहतर बना सकती है इसलिए वैज्ञानिक सोच जरुरी है | वैज्ञानिक सोच लोगो में जागृत हो सके इसलिए धर्मिक ठेकेदारों से हुई बात चित और उनका पक्ष सहित रेशनल और वैज्ञानिक सोच की डिबेट इस चैनल में जारी की जाएगी| उम्मीद है इस चैनल से आपलोगो को काफी कुछ सिखने को भी मिलेगा और आप भी किसी से बेहद ही तर्कपूर्ण ढंग से तर्क करना सिख सकेंगे| In this channel you will get various hot topics debate between religious and rational personality. This channel is totally dedicated to produce rational thinking among human citizens with scientific temperament.', 'resourceId': {'kind': 'youtube#channel', 'channelId': 'UCAsMzkkj5XJsRi58crN9bfw'}, 'channelId': 'UCjM6_UoeJI100P6d1G99bxg', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/T6ArQOByWIFBTpAUSNR8_CLTeJVGj0G_vdGmm7FUyPjEiLePQLunw8nfswdA7fGklQc_f2-8OQ=s88-c-k-c0x00ffffff-no-rj'}, 'medium': {'url': 'https://yt3.ggpht.com/T6ArQOByWIFBTpAUSNR8_CLTeJVGj0G_vdGmm7FUyPjEiLePQLunw8nfswdA7fGklQc_f2-8OQ=s240-c-k-c0x00ffffff-no-rj'}, 'high': {'url': 'https://yt3.ggpht.com/T6ArQOByWIFBTpAUSNR8_CLTeJVGj0G_vdGmm7FUyPjEiLePQLunw8nfswdA7fGklQc_f2-8OQ=s800-c-k-c0x00ffffff-no-rj'}}}, 'contentDetails': {'totalItemCount': 598, 'newItemCount': 0, 'activityType': 'all'}}, {'kind': 'youtube#subscription', 'etag': 'gc9T_eyc4I8G6K1bpNgb81fWOVA', 'id': 'SIHu8KibTrT4WSLhozvHNlTPRtAh2PC0sAxizNvVKIo', 'snippet': {'publishedAt': '2022-02-17T16:49:47.41443Z', 'title': 'Science Journey', 'description': '', 'resourceId': {'kind': 'youtube#channel', 'channelId': 'UCCnvxw3fhw1Kx4uDOD-4xqA'}, 'channelId': 'UCjM6_UoeJI100P6d1G99bxg', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AGIKgqMcuGsvlSv7KuYRVI5CYcls7l_5YX6-4OhyBOdw=s88-c-k-c0x00ffffff-no-rj'}, 'medium': {'url': 'https://yt3.ggpht.com/ytc/AGIKgqMcuGsvlSv7KuYRVI5CYcls7l_5YX6-4OhyBOdw=s240-c-k-c0x00ffffff-no-rj'}, 'high': {'url': 'https://yt3.ggpht.com/ytc/AGIKgqMcuGsvlSv7KuYRVI5CYcls7l_5YX6-4OhyBOdw=s800-c-k-c0x00ffffff-no-rj'}}}, 'contentDetails': {'totalItemCount': 267, 'newItemCount': 0, 'activityType': 'all'}}, {'kind': 'youtube#subscription', 'etag': 'HUy-1ws9z3gS0qQmbpDm29p9PS4', 'id': 'SIHu8KibTrTIIVKBOCVnFacbLJLfNJA1M628_UEJYOE', 'snippet': {'publishedAt': '2021-02-22T08:06:36.074185Z', 'title': 'All-In Podcast', 'description': 'Chamath Palihapitiya, Jason Calacanis, David Sacks & David Friedberg cover all things economic, tech, political, social & poker.\n\nFollow the besties: \nhttps://twitter.com/chamath\nhttps://linktr.ee/calacanis\nhttps://twitter.com/DavidSacks\nhttps://twitter.com/friedberg\n\nFollow the pod: \nhttps://twitter.com/theallinpod\nhttps://linktr.ee/allinpodcast\n\nWet Your Beak: https://thesyndicate.com/allin', 'resourceId': {'kind': 'youtube#channel', 'channelId': 'UCESLZhusAkFfsNsApnjF_Cg'}, 'channelId': 'UCjM6_UoeJI100P6d1G99bxg', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AGIKgqPnGjHyVjVokLhXfCmz5v81eYH6i63BKZZOy-P2=s88-c-k-c0x00ffffff-no-rj'}, 'medium': {'url': 'https://yt3.ggpht.com/ytc/AGIKgqPnGjHyVjVokLhXfCmz5v81eYH6i63BKZZOy-P2=s240-c-k-c0x00ffffff-no-rj'}, 'high': {'url': 'https://yt3.ggpht.com/ytc/AGIKgqPnGjHyVjVokLhXfCmz5v81eYH6i63BKZZOy-P2=s800-c-k-c0x00ffffff-no-rj'}}}, 'contentDetails': {'totalItemCount': 149, 'newItemCount': 0, 'activityType': 'all'}}, {'kind': 'youtube#subscription', 'etag': 'PnA0GnsRTJRlAoxiLrCAEtFXHlM', 'id': 'SIHu8KibTrSfgD97hfaCzwvjqErOR9JyrlWDJ50bUMc', 'snippet': {'publishedAt': '2020-04-16T20:30:41.260336Z', 'title': 'Lex Fridman', 'description': 'Lex Fridman Podcast and other videos.', 'resourceId': {'kind': 'youtube#channel', 'channelId': 'UCSHZKyawb77ixDdsGog4iWA'} ...

# %%
all_results[0]
# Out:
# {'kind': 'youtube#subscription',
#  'etag': 'Cx76hlf1aCuc1Y031-4FlGSEI18',
#  'id': 'SIHu8KibTrTIIVKBOCVnFQVre9G6BFtDmxV4zTg-SC4',
#  'snippet': {'publishedAt': '2022-02-17T16:49:00.36575Z',
#   'title': 'Rational World',
#   'description': 'यह चैनल समाज में फैले अंधविश्वास, पाखंड को तथा उसे फ़ैलाने वाले उसके ठेकेदारों को बेनकाब करने के लिए प्रतिबद्ध है ताकि मानव सभ्यता एक बेहतर जीवन जी सके | सिर्फ वैज्ञानिक सोच ही मानव भविष्य को बेहतर बना सकती है इसलिए वैज्ञानिक सोच जरुरी है | वैज्ञानिक सोच लोगो में जागृत हो सके इसलिए धर्मिक ठेकेदारों से हुई बात चित और उनका पक्ष सहित रेशनल और वैज्ञानिक सोच की डिबेट इस चैनल में जारी की जाएगी| उम्मीद है इस चैनल से आपलोगो को काफी कुछ सिखने को भी मिलेगा और आप भी किसी से बेहद ही तर्कपूर्ण ढंग से तर्क करना सिख सकेंगे| In this channel you will get various hot topics debate between religious and rational personality. This channel is totally dedicated to produce rational thinking among human citizens with scientific temperament.',
#   'resourceId': {'kind': 'youtube#channel',
#    'channelId': 'UCAsMzkkj5XJsRi58crN9bfw'},
#   'channelId': 'UCjM6_UoeJI100P6d1G99bxg',
#   'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/T6ArQOByWIFBTpAUSNR8_CLTeJVGj0G_vdGmm7FUyPjEiLePQLunw8nfswdA7fGklQc_f2-8OQ=s88-c-k-c0x00ffffff-no-rj'},
#    'medium': {'url': 'https://yt3.ggpht.com/T6ArQOByWIFBTpAUSNR8_CLTeJVGj0G_vdGmm7FUyPjEiLePQLunw8nfswdA7fGklQc_f2-8OQ=s240-c-k-c0x00ffffff-no-rj'},
#    'high': {'url': 'https://yt3.ggpht.com/T6ArQOByWIFBTpAUSNR8_CLTeJVGj0G_vdGmm7FUyPjEiLePQLunw8nfswdA7fGklQc_f2-8OQ=s800-c-k-c0x00ffffff-no-rj'}}},
#  'contentDetails': {'totalItemCount': 598,
#   'newItemCount': 0,
#   'activityType': 'all'}}

# %%
x=all_results[10]
pd.Series(x)
# Out:
# kind                                           youtube#subscription
# etag                                    cF70sgdl9RBSHUHomxxJ-HIibGM
# id                      SIHu8KibTrSZqdrxcBe2YNGJy5mbg0xZdXOtMUugx5A
# snippet           {'publishedAt': '2020-05-10T05:42:13.807587Z',...
# contentDetails    {'totalItemCount': 70, 'newItemCount': 0, 'act...
# dtype: object

# %%
def get_channels(results: list)->pd.DataFrame:
    
    channels = pd.DataFrame()
    for channel in all_results:
        channel = pd.DataFrame({
        'title' : channel['snippet']['title'],
        'description' : channel['snippet']['description'],
        'resourceId' : channel['snippet']['resourceId'],
        'channelId' : channel['snippet']['channelId'],
        'publishedAt' : channel['snippet']['publishedAt'],
        'totalItemCount' : channel['contentDetails']['totalItemCount'],
        })
        channels = pd.concat([channels, channel])
    channels = channels[channels.index == 'channelId'].reset_index(drop=True)
    return channels

df = get_channels(all_results)
df.describe(include='object')
# Out:
#                  title description                resourceId
# count              415         415                       415  \
# unique             415         389                       415
# top     Rational World              UCAsMzkkj5XJsRi58crN9bfw
# freq                 1          27                         1
#
#                        channelId                 publishedAt
# count                        415                         415
# unique                         1                         415
# top     UCjM6_UoeJI100P6d1G99bxg  2022-02-17T16:49:00.36575Z
# freq                         415                           1

# %%
duplicate_titles = channels.groupby('description')['title'].apply(lambda x: list(x) if len(x) > 1 else None).dropna()
duplicate_titles.reset_index()
# Out:
#   description                                              title
# 0              [Science Journey, Al Sweigart, Agnes Callard, ...

# %%
len(duplicate_titles)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 len(duplicate_titles)
#
# NameError: name 'duplicate_titles' is not defined
